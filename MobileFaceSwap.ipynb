# %% [markdown]
# <a href="https://colab.research.google.com/github/seinfinity/ComfyUI_windows_portable_for_faceswap/blob/main/MobileFaceSwap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MobileFaceSwap - Inference on CPU
# A notebook to execute face swap on your images or videos using the [MobileFaceSwap framework](https://arxiv.org/abs/2201.03808), using only CPUs. No need for hardware acceleration in order to execute the code in this notebook cells.
# Credits for the MobileFaceSwap paper:
#
#
# ```
# @inproceedings{xu2022MobileFaceSwap,
#   title={MobileFaceSwap: A Lightweight Framework for Video Face Swapping},
#   author={Xu, Zhiliang and Hong, Zhibin and Ding, Changxing and Zhu, Zhen and Han, Junyu and Liu, Jingtuo and Ding, Errui},
#   booktitle={Proceedings of the AAAI Conference on Artificial Intelligence},
#   year={2022}
# }
# ```

# %% [markdown]
# ## Settings

# %% [markdown]
# Clone the official GitHub repository.

# %%
# !git clone https://github.com/Seanseattle/MobileFaceSwap.git
# %cd MobileFaceSwap
# Out:
# Cloning into 'MobileFaceSwap'...
# remote: Enumerating objects: 40, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 40 (delta 2), reused 2 (delta 2), pack-reused 33
# Receiving objects: 100% (40/40), 22.22 MiB | 13.06 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/MobileFaceSwap

# %% [markdown]
# Install the missing dependencies in the Colab runtime (PaddlePaddle, InsightFace and ONNX Runtime).

# %%
# !pip install paddlepaddle==2.1.2
# !pip install paddlepaddle
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 MB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.5 MB/s eta 0:00:00
# ...

# %%
# !pip install insightface==0.2.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 38.1 MB/s eta 0:00:00
# ...

# %%
# !pip install onnxruntime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# Download the pretrained model.

# %%
# !gdown --id 1ZIzGLDB15GRAZAbkfNR0hNWdgQpxeA_r
# !tar -xvf ./checkpoints.tar
# !rm ./checkpoints.tar
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1ZIzGLDB15GRAZAbkfNR0hNWdgQpxeA_r
# From (redirected): https://drive.google.com/uc?id=1ZIzGLDB15GRAZAbkfNR0hNWdgQpxeA_r&confirm=t&uuid=9586abba-30a7-4412-9edf-d60165857571
# To: /content/MobileFaceSwap/checkpoints.tar
# 100% 569M/569M [00:07<00:00, 71.8MB/s]
# ._checkpoints
# checkpoints/
# checkpoints/._MobileFaceSwap_224.pdparams
# checkpoints/MobileFaceSwap_224.pdparams
# checkpoints/._landmarks
# checkpoints/landmarks/
# checkpoints/._arcface.pdparams
# checkpoints/arcface.pdparams
# checkpoints/landmarks/._glintr100.onnx
# checkpoints/landmarks/glintr100.onnx
# checkpoints/landmarks/._scrfd_10g_bnkps.onnx
# checkpoints/landmarks/scrfd_10g_bnkps.onnx

# %% [markdown]
# Create a directory where to store the uploaded images and/or videos.

# %%
# !mkdir ./data

# %% [markdown]
# Define a function to upload files to Colab.

# %%
import os
import shutil
from google.colab import files

def upload_files(upload_path):
  uploaded = files.upload()
  for filename, content in uploaded.items():
    dst_path = os.path.join(upload_path, filename)
    shutil.move(filename, dst_path)
  return list(uploaded.keys())

# %% [markdown]
# ## Inference

# %% [markdown]
# #### Image Swap

# %% [markdown]
# Upload your own images (source and target).

# %%
image_input_dir = '/content/MobileFaceSwap/data/'
uploaded_images = upload_files(image_input_dir)
# Out:
#      <input type="file" id="files-6cad98a6-988a-4025-8560-5bb46da3af63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6cad98a6-988a-4025-8560-5bb46da3af63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(uploaded_images)
# Out:
# ['hangwon.png', 'moon.png']

# %%
os.environ['TARGET_IMAGE'] = uploaded_images[0]
os.environ['SOURCE_IMAGE'] = uploaded_images[1]

# %% [markdown]
# Run inference.

# %%
# !python ./image_test.py --target_img_path data/$TARGET_IMAGE --source_img_path data/$SOURCE_IMAGE --output_dir results
# Out:
# input mean and std: 127.5 127.5
# find model: ./checkpoints/landmarks/glintr100.onnx recognition
# find model: ./checkpoints/landmarks/scrfd_10g_bnkps.onnx detection
# set det-size: (640, 640)
# /content/MobileFaceSwap/utils/align_face.py:30: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   A, res, rank, s = np.linalg.lstsq(src_pts_, dst_pts_)

# %% [markdown]
# Display the result.

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread(os.path.join('./results', uploaded_images[0]))
# cv2_imshow(img)

# %% [markdown]
# ### Video Swap

# %% [markdown]
# Upload your own source image and target video.

# %%
uploaded_image_and_video = upload_files(image_input_dir)
# Out:
#      <input type="file" id="files-25e75569-c076-4547-b1e0-2ece26e1f01f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-25e75569-c076-4547-b1e0-2ece26e1f01f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import fnmatch

uploaded_target_video = fnmatch.filter(uploaded_image_and_video, '*mp4')[0]
os.environ['TARGET_VIDEO'] = uploaded_target_video
os.environ['SOURCE_IMAGE'] = fnmatch.filter(uploaded_image_and_video, '*png')[0]

# %% [markdown]
# Run inference.

# %%
# !python ./video_test.py --target_video_path data/$TARGET_VIDEO --source_img_path data/$SOURCE_IMAGE --output_path results
# Out:
# input mean and std: 127.5 127.5
# find model: ./checkpoints/landmarks/glintr100.onnx recognition
# find model: ./checkpoints/landmarks/scrfd_10g_bnkps.onnx detection
# set det-size: (640, 640)
# /content/MobileFaceSwap/utils/align_face.py:30: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   A, res, rank, s = np.linalg.lstsq(src_pts_, dst_pts_)
# 100% 175/175 [01:55<00:00,  1.52it/s]

# %% [markdown]
# Display the result video.

# %%
from moviepy.editor import VideoFileClip

result_video_path = os.path.join('./results', uploaded_target_video)

clip = VideoFileClip(result_video_path)
clip.ipython_display(width=280)
# Out:
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video width='280'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
# !pip install gfpgan
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 19.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 57.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 21.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 16.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...

# %%
# Out:
# Cloning into 'GPEN'...
# remote: Enumerating objects: 671, done.
# remote: Counting objects: 100% (161/161), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 671 (delta 118), reused 110 (delta 109), pack-reused 510
# Receiving objects: 100% (671/671), 187.58 MiB | 22.27 MiB/s, done.
# Resolving deltas: 100% (187/187), done.
# Updating files: 100% (251/251), done.
# /content/MobileFaceSwap/GPEN
# mkdir: cannot create directory ‘experiments/pretrained_models’: No such file or directory
# experiments/pretrained_models/GPEN-BFR-512.pth: No such file or directory

# %%
# Out:
# ...
# Cloning into 'GFPGAN'...
# remote: Enumerating objects: 527, done.
# remote: Counting objects: 100% (213/213), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 527 (delta 170), reused 155 (delta 154), pack-reused 314
# Receiving objects: 100% (527/527), 5.38 MiB | 25.25 MiB/s, done.
# Resolving deltas: 100% (281/281), done.
# /content/MobileFaceSwap/GPEN/GFPGAN
# /usr/local/lib/python3.10/dist-packages/setuptools/__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
#         Requirements should be satisfied by a PEP 517 installer.
#         If you are using pip, you can try `pip install --use-pep517`.
#         ********************************************************************************
#
# !!
#   dist.fetch_build_eggs(dist.setup_requires)
# running develop
# ...

# %%
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 1.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 83.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 6.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 2.3.0
#     Uninstalling triton-2.3.0:
#       Successfully uninstalled triton-2.3.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.0+cu121
#     Uninstalling torch-2.3.0+cu121:
#       Successfully uninstalled torch-2.3.0+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.18.0+cu121
#     Uninstalling torchvision-0.18.0+cu121:
#       Successfully uninstalled torchvision-0.18.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...
